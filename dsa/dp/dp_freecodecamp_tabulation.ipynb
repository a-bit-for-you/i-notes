# %% [markdown]
# # Tabulation recipe

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Fibo

# %%
def fibo(n):
    arr = [0 for i in range(n+1)]
    arr[1] = 1

    for i in range(n-1):
        arr[i+1] += arr[i]
        arr[i+2] += arr[i]
    arr[-1] = arr[-2] + arr[-3]
    return arr[n]

fibo(5)
# Out:
# 5

# %% [raw]
# time and space complexity O(n)

# %% [markdown]
# # 2. Grid traveler

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
def grid_traveler(r,c):
    table = [[0 for j in range(c+1)] for i in range(r+1)]
    table[1][1] = 1
    for i in range(r+1):
        for j in range(c+1):
            current = table[i][j] 
            if i < r:
                table[i+1][j] += current # down neighbor
            if j < c:
                table[i][j+1] += current  # right neighbor
    return table[r][c]

print(grid_traveler(1,1))
print(grid_traveler(2,3))
print(grid_traveler(3,2))
print(grid_traveler(3,3))
print(grid_traveler(18,18))
# Out:
# 1
# 3
# 3
# 6
# 2333606220

# %% [raw]
# time & space complexity m*n

# %% [markdown]
# # 3. canSum

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def can_sum(target_sum, numbers):
    
    table = [False for i in range(target_sum+1)]
    table[0] =  True
    for i in range(target_sum):
        if table[i]:
            for number in numbers:
                if i+number <= target_sum:
                    table[i+number] = True
    return table[target_sum]

print(can_sum(7, [5,3,4]))
print(can_sum(7, [2,3]))
print(can_sum(7, [5,3,4,7]))
print(can_sum(7, [2,4]))
print(can_sum(8, [2,3,5]))
print(can_sum(300, [7,14]))
# Out:
# True
# True
# True
# False
# True
# False

# %% [raw]
# time and space complexity is 2 cell above

# %% [markdown]
# # 4. howSum

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def how_sum(target_sum, numbers):
    
    table = [None for i in range(target_sum+1)]
    table[0] = []
    for i in range(target_sum):
        if table[i] != None:
            for number in numbers:
                if i+number <= target_sum:
                    table[i+number] = table[i] + [number]
    return table[target_sum]  

print(how_sum(7, [5,3,4]))
print(how_sum(7, [2,3]))
print(how_sum(7, [5,3,4,7]))
print(how_sum(7, [2,4]))
print(how_sum(8, [2,3,5]))
print(how_sum(300, [7,14]))
# Out:
# [4, 3]
# [3, 2, 2]
# [4, 3]
# None
# [2, 2, 2, 2]
# None

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. bestSum

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def best_sum(target_sum, numbers):
    
    table = [None for i in range(target_sum+1)]
    table[0] = []
    
    for i in range(target_sum):
        
        if table[i] != None:
            for number in numbers:
                if i+number <= target_sum:
                    combination = table[i]  + [number]
                
                    if not table[i+number] or len(combination) < len(table[i+number]):
                        table[i+number] = combination
                        
    return table[target_sum]

# print(best_sum(8, [2,3,5]))
print(best_sum(7, [5,3,4,7]))
print(best_sum(8, [2,3,5]))
print(best_sum(8, [1,4,5]))
print(best_sum(100, [1,2,5,25]))
print(best_sum(100, [25,1,5,2]))
# Out:
# [7]
# [3, 5]
# [4, 4]
# [25, 25, 25, 25]
# [25, 25, 25, 25]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. can_construct

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def can_construct(target, wordBank):
    table = [False for i in range(len(target)+1)]
    table[0] = True
    for i in range(len(target)):
        if table[i]:
            for word in wordBank:
                len_word = len(word)
                if target[i:i+len_word] == word:
                    table[i+len_word] = True
    return table[-1]
    
print(can_construct('abcdef', ['ab', 'abc', 'cd', 'def', 'abcd']))
print(can_construct('skateboard', ['bo', 'rd', 'ate', 't', 'ska', 'sk', 'boar']))
print(can_construct('enterapotentpot', ['a', 'p', 'ent', 'enter', 'ot', 'o', 't']))
print(can_construct('eeeeeeeeeeeeeeeeeeeeeeef', ['e', 'ee', 'eee', 'eeeee', 'eeeeeeee']))
# Out:
# True
# False
# True
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. count_construct

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_construct(target, wordBank):
    table = [0 for i in range(len(target)+1)]
#     print(table)
    table[0] = 1
    
    for i in range(len(target)):
        if table[i] != 0:
            for word in wordBank:
                len_word = len(word)
                if target[i:i+len_word] == word:
                    table[i+len_word] += table[i]
#     print(table)
    return table[-1]
print(count_construct('purple', ['purp', 'p', 'ur', 'le', 'purpl']))
print(count_construct('abcdef', ['ab', 'abc', 'cd', 'def', 'abcd']))
print(count_construct('skateboard', ['bo', 'rd', 'ate', 't', 'ska', 'sk', 'boar']))
print(count_construct('enterapotentpot', ['a', 'p', 'ent', 'enter', 'ot', 'o', 't']))
print(count_construct('eeeeeeeeeeeeeeeeeeeeeeef', ['e', 'ee', 'eee', 'eeeee', 'eeeeeeee']))
# Out:
# 2
# 1
# 0
# 4
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. all_construct

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def all_construct(target, wordBank):
    table = [[] for i in range(len(target)+1)]
    table[0] = [[]]
    result = []
    for i in range(len(target)):
        if table[i] != []:
            for word in wordBank:
                len_word = len(word)
                if target[i:i+len_word] == word:
                    combination = list(map(lambda x: x+[word], table[i]))
                    table[i+len_word] = table[i+len_word] + combination

    return table[-1]
    
    
print(all_construct('purple', ['purp', 'p', 'ur', 'le', 'purpl']))
print(all_construct('abcdef', ['ab', 'abc', 'cd', 'def', 'abcd', 'ef', 'c']))
print(all_construct('skateboard', ['bo', 'rd', 'ate', 't', 'ska', 'sk', 'boar']))
print(all_construct('aaaaaaaaaaz', ['a', 'aa', 'aaa', 'aaa', 'aaaa']))
# Out:
# [['purp', 'le'], ['p', 'ur', 'p', 'le']]
# [['abc', 'def'], ['ab', 'c', 'def'], ['abcd', 'ef'], ['ab', 'cd', 'ef']]
# []
# []

# %% [markdown]
# ![image.png](attachment:image.png)
